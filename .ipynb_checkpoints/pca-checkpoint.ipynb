# %% [markdown]
# # Data Analysis and Mining 2018/ 2019
#
# ## Principal Component Analysis and Singular Value Decomposition

# %%
# Numpy for data management
import numpy as np

# Pandas also for data management
import pandas as pd

# Matplotlib for additional customization
from matplotlib import pyplot as plt
# %matplotlib inline

# Seaborn for plotting and styling
import seaborn as sns
sns.set_style("darkgrid")

# ?????? Sklearn for data import and scalers
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

#interactive plot
from plotly.offline import plot
from plotly.graph_objs import *
from numpy import genfromtxt
from mpl_toolkits.mplot3d import Axes3D

# %%
data = genfromtxt('./tripadvisor_review.csv', delimiter=',')
data = data[1:,1:]
data = data[:,3:6]
data
# Out:
# array([[0.62, 0.8 , 2.42],
#        [0.64, 1.42, 3.18],
#        [0.53, 0.24, 1.54],
#        ...,
#        [0.43, 1.3 , 1.78],
#        [0.43, 0.3 , 0.4 ],
#        [0.51, 1.34, 2.36]])

# %%
classes = np.rint(data[:, -1])
len(classes[classes == 4])
# Out:
# 1

# %%
plt.xticks(np.arange(5), ('class 0', 'class 1', 'class 2', 'class 3', 'class 4'))
plt.hist(classes, 5)
plt.show()

# %% [markdown]
# We want to check how people who are interested in religious institutions are interested also in other categories. The classes are based on the average feedback on this category rounded to the nearest integer (classes 0, 1, 2, 3, 4).

# %%
def visualize3D(data, classes):
    names = ["PC_"+str(x+1) for x in range(data.shape[1])]
    names.append('target')
    data_pca = pd.DataFrame(data= np.c_[data, classes], 
                     columns=names)
    data_pca['target'] = data_pca['target'].astype(int)

    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    ax.scatter(data_pca['PC_1'], 
               data_pca['PC_2'],
               data_pca['PC_3'],
               c=data_pca['target']);

    ax.set_xlabel('PC 1')
    ax.set_ylabel('PC 2')
    ax.set_zlabel('PC 3')
    ax.set_title('PC Projection of Travel Reviews Data');

# %%
visualize3D(data, classes)

# %% [markdown]
# We chosen both the last two features from our Regression analysis plus another one which is average feedback on restaurants. The reason why we chose them is because of the fact that we noticed a *'linear-like'* dependency between average feedback on museums and resorts, and they all seem to be related to the same aspect of the phenomenon to which our dataset relates to.

# %% [markdown]
# __Visualization of the data over chosen features using two types of normalization__

# %%
def visualizeSVD(center_data):
    u, s, vh = np.linalg.svd(center_data, full_matrices=True)
    project_data_featureloading = np.dot(center_data, vh.T) # Transpose feature loadings 'vh'
    v_norm = np.dot(vh.T,vh)
    Us_eig = np.dot(u[:,0:3], np.diag(s[0:3]))
    return Us_eig

# %% [markdown]
# // maybe PCA visualisation?

# %%
def explained_variance_plot(x_norm):
    ## Covariance matrix of the normalized dataset
    covmatrix = np.cov(x_norm.T)
    
    ## Obtain the eingenvalues and eingenvectors of covariance matrix
    # The eigenvalues are not necessarily ordered
    e, v = np.linalg.eig(covmatrix)

    totVar = sum(e)       #Total variability of the Data
    var_exp = [(i / totVar)*100 for i in sorted(e, reverse=True)]
    cum_var_exp = np.cumsum(var_exp)

    trace1 = Bar(
            x=['PC %s' %i for i in range(1,5)],
            y=var_exp,
            name='Exp Var',
            showlegend=False)

    trace2 = Scatter(
            x=['PC %s' %i for i in range(1,5)], 
            y=cum_var_exp,
            name='Cum. Exp Var')

    data = Data([trace1, trace2])

    layout=Layout(
            yaxis=YAxis(title='Explained variance in percent'),
            title='Explained variance by different principal components')

    fig = Figure(data=data, layout=layout)
    plot(fig)

# %%
row_mean = np.mean(data, axis=0)
center_data = data - row_mean
print(center_data)
# Out:
# [[ 0.0875     -0.13973469  0.57710204]
#  [ 0.1075      0.48026531  1.33710204]
#  [-0.0025     -0.69973469 -0.30289796]
#  ...
#  [-0.1025      0.36026531 -0.06289796]
#  [-0.1025     -0.63973469 -1.44289796]
#  [-0.0225      0.40026531  0.51710204]]

# %% [markdown]
# - by range

# %%
normalized_data1 = center_data.copy()

for i in range(3):
    normalized_data1[:,i] = normalized_data1[:,i] / (max(normalized_data1[:,i]) - min(normalized_data1[:,i]))

normalized_data1
# Out:
# array([[ 0.02659574, -0.04312799,  0.15942045],
#        [ 0.03267477,  0.14823003,  0.3693652 ],
#        [-0.00075988, -0.2159675 , -0.08367347],
#        ...,
#        [-0.03115502,  0.111193  , -0.01737513],
#        [-0.03115502, -0.19744898, -0.3985906 ],
#        [-0.00683891,  0.12353867,  0.14284587]])

# %%
visualize3D(normalized_data1, classes)

# %%
visualize3D(visualizeSVD(normalized_data1), classes)

# %% [markdown]
# Explained variance by different principal components plot for data normalized by range __+ generally  Discuss your results and calculate quality from formula!!__

# %%
explained_variance_plot(normalized_data1)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\plotly\graph_objs\_deprecations.py:39: DeprecationWarning:
#
# plotly.graph_objs.Data is deprecated.
# Please replace it with a list or tuple of instances of the following types
#   - plotly.graph_objs.Scatter
#   - plotly.graph_objs.Bar
#   - plotly.graph_objs.Area
#   - plotly.graph_objs.Histogram
#   - etc.
#
#
# C:\Users\User\Anaconda3\lib\site-packages\plotly\graph_objs\_deprecations.py:558: DeprecationWarning:
#
# plotly.graph_objs.YAxis is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.YAxis
#   - plotly.graph_objs.layout.scene.YAxis

# %% [markdown]
# - by standard deviations

# %%
normalized_data2 = center_data.copy()

for i in range(3):
    normalized_data2[:,i] = normalized_data2[:,i] / np.std(normalized_data2[:,i])

normalized_data2
# Out:
# array([[ 0.31295986, -0.31960783,  1.07016867],
#        [ 0.38449354,  1.09848562,  2.47950035],
#        [-0.00894171, -1.60046643, -0.56168906],
#        ...,
#        [-0.36661012,  0.82401592, -0.11663696],
#        [-0.36661012, -1.46323158, -2.67568658],
#        [-0.08047539,  0.91550582,  0.95890564]])

# %%
visualize3D(normalized_data2, classes)

# %%
visualize3D(visualizeSVD(normalized_data2), classes)

# %% [markdown]
# Explained variance by different principal components plot for data normalized by standard deviation

# %%
explained_variance_plot(normalized_data2)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\plotly\graph_objs\_deprecations.py:39: DeprecationWarning:
#
# plotly.graph_objs.Data is deprecated.
# Please replace it with a list or tuple of instances of the following types
#   - plotly.graph_objs.Scatter
#   - plotly.graph_objs.Bar
#   - plotly.graph_objs.Area
#   - plotly.graph_objs.Histogram
#   - etc.
#
#
# C:\Users\User\Anaconda3\lib\site-packages\plotly\graph_objs\_deprecations.py:558: DeprecationWarning:
#
# plotly.graph_objs.YAxis is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.YAxis
#   - plotly.graph_objs.layout.scene.YAxis

# %% [markdown]
# __Conclusions__

# %% [markdown]
# Although, the cumulated explained variance is slightly higher for 2 first principal components when we normalize data by standard deviation (86.44% by standard deviation, 86.36% by range), when we normalize by range the first principal component explains variance more (68.00% by range, 55.29% by standard deviation) and there is a bigger difference between first and second component, so we consider it better way of normalization. Therefore, we will use it in our subsequent considerations.

# %%
'''fig, [ax1,ax2] = plt.subplots(ncols=2, figsize=(16,4))

sns.regplot(x= project_data_featureloading[:,0],
            y= project_data_featureloading[:,1],
            fit_reg=False,
            scatter_kws={'alpha':0.3},ax=ax1)
ax1.quiver(0, 0, v_norm[0,0],v_norm[1,0], scale_units='xy', angles='xy', scale=1, color = '#b2df8a')
ax1.quiver(0, 0, v_norm[0,1],v_norm[1,1], scale_units='xy', angles='xy', scale=1, color = '#e41a1c')
ax1.set(xlabel='Projection onto SingularFeatureLoading/EigenVector 1', 
       ylabel='Projection onto SingularFeatureLoading/EigenVector 2',
       title=' SVD Projection of Multivariate Gaussian Data');

sns.regplot(x=Us_eig[:,0],
            y=Us_eig[:,1],
            fit_reg=False,
            scatter_kws={'alpha':0.3},ax=ax2)
ax2.quiver(0, 0, v_norm[0,0],v_norm[1,0], scale_units='xy', angles='xy', scale=1, color = '#b2df8a')
ax2.quiver(0, 0, v_norm[0,1],v_norm[1,1], scale_units='xy', angles='xy', scale=1, color = '#e41a1c')
ax2.set(xlabel='', 
       ylabel='',
       title='SVD US');''';

# %%
'''
## Obtain the eingenvalues and eingenvectors of covariance matrix
# The eigenvalues are not necessarily ordered
e, v = np.linalg.eig(covmatrix)

# order descendingly by largest eigenvalue
order = np.argsort((np.argsort(e) * -1))
e = e[order]
v = v[:,order]

print('Eigenvectors \n%s' %e)
print('\nEigenvalues \n%s' %v)

# generate PCA component space (PCA scores)
pc = np.dot(x_norm, v)

u, s, vh = np.linalg.svd(x_norm, full_matrices=True)

## Calculate the coordinates of the data points in the projection axes of the space spanned 
## by the leading eigenvectors contained in $U$ 
u1 = u[:,0] * s[0] 
u2 = u[:,1] * s[1] 
''';

# %% [markdown]
# // is it necessary??

# %%
r = x_values.shape[1]
var_explained = np.cumsum(s**2)/np.sum(s**2)*100;

# You can change the features you would like to display, from 0 to 3
f1=0   #Sepal lenght
f2=2   #Petal lenght

approx = []
for n in range(1,r+1):
    approximation = np.dot((u[:,:n] * s[:n]),vh[:n,:]) 
    
    approx.append(approximation)
    
    fig, [ax1,ax2] = plt.subplots(ncols=2, figsize=(16,4))
    
    sns.regplot(x=approximation[:,f1],
                y=approximation[:,f2],
                fit_reg=False,
                scatter_kws={'alpha':0.3}, ax=ax1)
    ax1.set(xlabel= 'Sepal lenght', 
           ylabel= 'Petal lenght',
           title= (str(n) 
                   + ' component(s) retained, ' 
                   + str(round(var_explained[n-1],2)) 
                   + '% variance'))
    

    sns.regplot(x=x_norm[:,f1],
                y=x_norm[:,f2],
                fit_reg=False,
                scatter_kws={'alpha':0.3}, ax=ax2)
    ax2.set(xlabel='Sepal lenght', 
           ylabel= 'Petal lenght',
           title=' Dataset');

# %% [markdown]
# __Computation and interpretation of a hidden factor behind the selected features__

# %%
X = data.copy()

for i in range(3):
    X[:,i] = (X[:,i] / max(X[:,i])) * 100

Z, Mu, C = np.linalg.svd(X, full_matrices=True)
Z = - Z[:, 0]
Mu = Mu[0]
C = - C[0]
print(Z, Mu, C)
# Out:
# [0.03656519 0.05026214 0.02168414 0.02333073 0.03755455 0.02136747
#  0.02619044 0.02530192 0.03357001 0.03050963 0.04772265 0.03234465
#  0.02947698 0.0314391  0.0441167  0.03734985 0.0144672  0.03356789
#  0.04686649 0.0343126  0.03611963 0.03390863 0.02525368 0.02640689
#  0.03399302 0.02376656 0.04336292 0.03154911 0.01445965 0.05258744
#  0.03535337 0.03251765 0.04347242 0.03874303 0.02516929 0.02498324
#  0.01705265 0.02163711 0.02850132 0.02032575 0.03456682 0.01679923
#  0.03113825 0.02951947 0.03300577 0.02382371 0.02645002 0.02969182
#  0.02530298 0.03566191 0.03199175 0.02551521 0.04684506 0.02922146
#  0.0260716  0.02084798 0.03667812 0.02659141 0.04622591 0.04115873
#  0.05092002 0.01244582 0.01692781 0.02106339 0.03065192 0.0280625
#  0.01513635 0.02572324 0.02444826 0.0230178  0.02379923 0.03204575
#  0.03304816 0.02853091 0.03133355 0.03498993 0.02209434 0.03625404
#  0.01780351 0.03582973 0.025377   0.02793213 0.01879079 0.03024034
#  0.03142386 0.02672031 0.02529334 0.01579949 0.03476732 0.02679157
#  0.02462037 0.01649863 0.039654   0.04622591 0.04670604 0.02830222
#  0.03416246 0.02960378 0.03056023 0.04133212 0.03225523 0.01935575
#  0.04393065 0.01718423 0.01761884 0.02255352 0.04243994 0.02060964
#  0.03193386 0.04109046 0.03077004 0.02340012 0.03121851 0.02780339
#  0.03204575 0.03435962 0.03113202 0.03092066 0.02579531 0.02961326
#  0.04860395 0.03673145 0.03834238 0.03976823 0.03395533 0.02610419
#  0.02206029 0.03148021 0.03064875 0.02753976 0.0251076  0.04702715
#  0.03638958 0.04061499 0.02871575 0.04348882 0.03083457 0.03632959
#  0.03099622 0.01764462 0.03268821 0.02526423 0.03262457 0.02537036
#  0.0321016  0.03234465 0.04317888 0.04130027 0.03643782 0.04083088
#  0.03419731 0.03254797 0.02100834 0.02941003 0.02646268 0.02762374
#  0.03571817 0.0173368  0.04006931 0.01629863 0.02514303 0.01539187
#  0.03121851 0.02426327 0.02460732 0.02365274 0.02784198 0.02964642
#  0.02815945 0.02315408 0.04076546 0.01955817 0.01694224 0.02198579
#  0.03148021 0.03657038 0.03326072 0.02327439 0.0298641  0.02535089
#  0.01476489 0.04581306 0.03270548 0.02122666 0.04839049 0.03567206
#  0.03761276 0.02265705 0.03676584 0.01646474 0.02812597 0.03213686
#  0.02823484 0.03382091 0.03223414 0.02481834 0.02334978 0.04243937
#  0.02119999 0.03425205 0.05021933 0.03150842 0.02797915 0.02382371
#  0.02654196 0.01182613 0.03087203 0.02292117 0.01978882 0.02533905
#  0.02754324 0.0355759  0.03189796 0.01974723 0.01524384 0.04595339
#  0.02341325 0.02450794 0.05105872 0.03545121 0.04233682 0.01768743
#  0.02845989 0.02403263 0.04782277 0.02742836 0.03342506 0.0310541
#  0.02791251 0.03521919 0.02722812 0.04264569 0.02036862 0.02363498
#  0.04455283 0.03223414 0.03971699 0.03517031 0.03754247 0.00297645
#  0.02797915 0.04331321 0.01642972 0.01833111 0.01354179 0.02649372
#  0.01404207 0.05321016 0.02440108 0.03223414 0.03552279 0.02583406
#  0.02928932 0.03294862 0.02155573 0.03487594 0.02599928 0.03989211
#  0.01664772 0.03646206 0.03361541 0.04765212 0.02991654 0.03684454
#  0.02699043 0.03734953 0.04042221 0.03091402 0.02635307 0.0424294
#  0.03779849 0.02252304 0.03863357 0.04102382 0.03893551 0.02526017
#  0.02964415 0.04139739 0.01444109 0.03589425 0.03008719 0.03434397
#  0.02848535 0.04101385 0.03111888 0.01397122 0.05248336 0.02597391
#  0.03340543 0.03305149 0.04270917 0.02220379 0.0253731  0.02094624
#  0.01445965 0.02481381 0.02872053 0.02273001 0.0276706  0.03278737
#  0.02042586 0.02389164 0.0208     0.02392667 0.03853939 0.02533687
#  0.03871441 0.04393744 0.02049275 0.03519309 0.02389635 0.02452107
#  0.02534262 0.04309449 0.03954998 0.02872807 0.04017559 0.02832921
#  0.02201458 0.02203046 0.03016802 0.02363045 0.0374623  0.01322716
#  0.02359485 0.04335602 0.03593795 0.05315136 0.0313197  0.03436627
#  0.03549992 0.03461984 0.0280625  0.03962652 0.01534283 0.03846414
#  0.03132876 0.01761641 0.04911197 0.02156415 0.04892717 0.03914415
#  0.0339207  0.03259531 0.034522   0.01750745 0.0345164  0.02491466
#  0.03283892 0.04546268 0.02697536 0.02234745 0.04184952 0.01680345
#  0.02368565 0.01921712 0.03354204 0.00975935 0.0436747  0.01497372
#  0.01794442 0.04236065 0.04670604 0.02182738 0.03853938 0.03332339
#  0.03436837 0.03276896 0.02692274 0.04290122 0.02486026 0.02791827
#  0.04111163 0.04384908 0.02995951 0.03653609 0.04901246 0.03284208
#  0.02226134 0.03590479 0.01737904 0.01987661 0.03127153 0.02074187
#  0.00601428 0.04299194 0.04172977 0.03333199 0.02750806 0.02458779
#  0.03672003 0.02111422 0.04144198 0.02184198 0.03392914 0.03457898
#  0.02847724 0.03083279 0.01852681 0.03052408 0.02896625 0.03438767
#  0.03029773 0.01881048 0.0347965  0.03837821 0.02783355 0.04546268
#  0.0303394  0.0432529  0.02995367 0.04148511 0.03028557 0.03030901
#  0.03989957 0.03938007 0.02518632 0.01107964 0.02646689 0.05369388
#  0.03418645 0.02473452 0.04122139 0.0253577  0.03906341 0.03193468
#  0.03685451 0.02282201 0.02001735 0.03199175 0.03569719 0.04621776
#  0.03487399 0.04812337 0.0424906  0.02315198 0.02683048 0.03947851
#  0.0307244  0.02612073 0.02236236 0.01850055 0.0318027  0.04090927
#  0.03621561 0.01749934 0.03457567 0.02528295 0.03841518 0.03622258
#  0.02004118 0.02204668 0.03132212 0.04231664 0.02164222 0.0387547
#  0.02593038 0.01781357 0.03951561 0.02347909 0.03553577 0.03456682
#  0.03692594 0.03079632 0.02533022 0.03777312 0.0205263  0.02453096
#  0.02619449 0.02917639 0.03646514 0.02818117 0.01966868 0.0332133
#  0.0207687  0.03407953 0.02022886 0.0162041  0.04210854 0.05952313
#  0.02482524 0.03041487 0.01453741 0.03915412 0.04353316 0.02286499
#  0.03616933 0.04938933 0.02956324 0.02968404 0.02122666 0.02557147
#  0.02216098 0.03266706 0.02402266 0.03590301 0.02574586 0.03986535
#  0.03198299 0.03695399 0.02956048 0.03790493 0.02853091 0.0250532
#  0.03363454 0.02876017 0.0267649  0.0530226  0.04947105 0.01899321
#  0.04199041 0.02074187 0.02475982 0.04678955 0.02897395 0.03663215
#  0.02367365 0.03648622 0.03252811 0.03648606 0.01851806 0.04031139
#  0.02812597 0.02611505 0.04292473 0.04712906 0.04077948 0.0320104
#  0.02841936 0.02355172 0.02943564 0.02412424 0.03360032 0.0290157
#  0.03028484 0.02514303 0.05710284 0.03223171 0.04771607 0.03563347
#  0.02892588 0.02341399 0.0232195  0.03246479 0.0340916  0.02590265
#  0.03167396 0.02028837 0.03223561 0.02787846 0.02802049 0.04839049
#  0.03151296 0.03625267 0.03728321 0.02691082 0.02109428 0.02609211
#  0.02638565 0.03597929 0.03139281 0.03339563 0.03603337 0.02889539
#  0.03428455 0.03681641 0.03170258 0.03104368 0.0367672  0.03909535
#  0.04018552 0.02304196 0.03656056 0.02183898 0.0399508  0.04101385
#  0.03386461 0.02779132 0.0215468  0.03144454 0.03056826 0.04070758
#  0.03631209 0.02609997 0.02840955 0.02033271 0.02062489 0.02477222
#  0.02867408 0.03987216 0.02749436 0.02804854 0.02692114 0.04265234
#  0.02325404 0.02440952 0.02682927 0.03269462 0.03017417 0.02598494
#  0.02096375 0.03842429 0.0338501  0.01205993 0.04652599 0.03216118
#  0.02544574 0.02537246 0.04475496 0.01717199 0.02641922 0.04016757
#  0.03620767 0.02448637 0.03134985 0.03030129 0.03038067 0.02472909
#  0.03863407 0.02439444 0.02828186 0.04175977 0.02631026 0.0307051
#  0.0166726  0.02076578 0.05512117 0.02658087 0.02189897 0.02787335
#  0.02307811 0.01683377 0.02277751 0.04782277 0.02114373 0.03424384
#  0.04815563 0.03598797 0.02709396 0.02317353 0.03895316 0.04294824
#  0.03134605 0.02421138 0.05096209 0.02146362 0.02644711 0.0250939
#  0.0341691  0.04625262 0.02928355 0.01629125 0.02146362 0.02384268
#  0.03118009 0.04224967 0.02740891 0.03787777 0.02564112 0.02848988
#  0.02292855 0.02486204 0.02784198 0.03759436 0.00884359 0.02749501
#  0.05219097 0.03738464 0.02300969 0.03012294 0.02862285 0.04963701
#  0.0136634  0.02053004 0.02885859 0.01971618 0.01806553 0.04415212
#  0.02736368 0.02699043 0.027791   0.02516929 0.03665792 0.02384268
#  0.03881056 0.03850153 0.03538141 0.02906241 0.02191542 0.03398848
#  0.02602174 0.02648229 0.011717   0.02571571 0.0521787  0.0408933
#  0.03250006 0.03162703 0.0146505  0.02061613 0.02511677 0.04291298
#  0.03535361 0.03419504 0.02415026 0.0173077  0.02674755 0.04218879
#  0.02483214 0.02368338 0.04027037 0.03528551 0.02260402 0.04111973
#  0.02132946 0.01639616 0.02084134 0.02780729 0.03494211 0.03693421
#  0.03645047 0.02371427 0.04468361 0.02559929 0.01882466 0.04383133
#  0.03862742 0.03685793 0.03337075 0.04855725 0.03011889 0.03568527
#  0.02751982 0.03006068 0.01926997 0.02689752 0.03712538 0.03885231
#  0.04160931 0.03491518 0.04424827 0.0401195  0.02928826 0.03311991
#  0.02220922 0.0280638  0.02364008 0.03913622 0.02398471 0.03197229
#  0.04373332 0.0208522  0.03734953 0.02747433 0.03849366 0.03160342
#  0.02098288 0.02593038 0.02020203 0.02052841 0.04016757 0.03007934
#  0.03631257 0.02477068 0.03779378 0.01980844 0.02552122 0.04360159
#  0.04295757 0.02033466 0.03556381 0.00938254 0.0236131  0.02209402
#  0.02254988 0.04232978 0.03190176 0.04273722 0.02206598 0.02304196
#  0.04117201 0.03034588 0.03179393 0.01513034 0.02351678 0.03197967
#  0.03083911 0.0292543  0.03450861 0.04263231 0.02838741 0.04075881
#  0.04558526 0.01667033 0.03541546 0.04831526 0.0240961  0.01874051
#  0.03322725 0.02930723 0.01587213 0.03806545 0.0313993  0.01719144
#  0.03802459 0.04767385 0.03370328 0.0315761  0.02956048 0.02975765
#  0.03920114 0.04474636 0.04267423 0.0322373  0.03569872 0.03300804
#  0.02792232 0.02559313 0.03265951 0.02812597 0.03838697 0.03485755
#  0.03324443 0.04027823 0.02922949 0.02187692 0.02212928 0.02189038
#  0.03118009 0.05240707 0.02174761 0.02635396 0.02675485 0.01411203
#  0.02691082 0.04097259 0.0370028  0.03147827 0.01767534 0.03294837
#  0.02729963 0.02257947 0.02497149 0.0171942  0.01450051 0.03480631
#  0.02578266 0.02700049 0.0145293  0.01807639 0.03179516 0.04074284
#  0.03404969 0.03938655 0.0478445  0.02849143 0.03938655 0.0314391
#  0.0290615  0.0288393  0.03141616 0.03587148 0.02850132 0.03468016
#  0.02018938 0.02621274 0.03319108 0.0632847  0.02069331 0.03208895
#  0.04436692 0.02189459 0.03556625 0.02448694 0.02733489 0.0272278
#  0.0419755  0.02300458 0.02811681 0.041704   0.02909621 0.02216957
#  0.03377973 0.03294862 0.04344257 0.0268814  0.02352943 0.01475451
#  0.03721213 0.01295745 0.03820546 0.03362068 0.03256199 0.02149962
#  0.02389635 0.02228892 0.05039745 0.02528385 0.0218414  0.0222089
#  0.02483432 0.03693016 0.03998477 0.03944825 0.02755289 0.03382602
#  0.01769011 0.03256199 0.03434397 0.02846897 0.00768041 0.03747437
#  0.02353761 0.02360296 0.03708355 0.03540233 0.03977439 0.02819536
#  0.01546727 0.0190583  0.03727746 0.01635214 0.03039064 0.02592478
#  0.02947698 0.03939361 0.03614403 0.02209402 0.03544109 0.02764239
#  0.03400721 0.03876143 0.02613045 0.02342785 0.02222276 0.0216813
#  0.02844287 0.04417141 0.04530427 0.05098803 0.03686174 0.02828803
#  0.03446006 0.02831834 0.0379076  0.03504449 0.02652225 0.02125496
#  0.03991164 0.04045302 0.02256924 0.03099258 0.03904453 0.02191454
#  0.02105375 0.03566191 0.0432208  0.02318667 0.02256965 0.03429842
#  0.03335776 0.03420048 0.02567095 0.02800567 0.03916767 0.04115531
#  0.03443549 0.02670037 0.03546638 0.01593074 0.03002404 0.0330403
#  0.02341359 0.03545859 0.04442694 0.02485102 0.02694868 0.03236709
#  0.00862154 0.03967767] 1915.922482293462 [0.25433134 0.4951353  0.83075665]

# %%
alpha = 100 / sum(C * 100)
hidden_factor_coeff = C * alpha
print(hidden_factor_coeff)
# Out:
# [0.16094646 0.31333249 0.52572105]

# %% [markdown]
# Therefore, our final equation would be:
# $Z = 0.16 * Restaurants + 0.31 * Museums + 0.53 * Resorts$

# %% [markdown]
# As we can see, weight of Average feedback on Resorts is the highest and is increased in the comparision to the mean, so it has the biggest contribution to the hidden factor. On the other hand, the weight of Average feedback on Restaurants and Museums is lowered in comparision to the mean.

# %%
hidden_factor = []

for i in range(len(X)):
    hidden_factor.append(np.dot(X[i], hidden_factor_coeff))

print(np.array(hidden_factor))
# Out:
# [44.33302006 60.93972306 26.29067204 28.28706352 45.53255293 25.90673431
#  31.75428071 30.67700916 40.70154806 36.99103383 57.8607432  39.21587117
#  35.73901033 38.11795021 53.48875131 45.28436825 17.54058242 40.69898267
#  56.82270142 41.60188931 43.79280144 41.11210454 30.61852198 32.01671626
#  41.21442606 28.81547508 52.57483892 38.25133887 17.53143244 63.75900386
#  42.86375745 39.42563004 52.70761233 46.97351478 30.51620046 30.29062761
#  20.67528308 26.2336536  34.5560778  24.64370505 41.91012428 20.36802318
#  37.75319315 35.79052589 40.01744364 28.88476704 32.0690059  35.99948347
#  30.67829186 43.23785054 38.78800475 30.93561157 56.79672024 35.42919999
#  31.61019392 25.27688195 44.46993424 32.24043332 56.04604306 49.90239634
#  61.73735575 15.08978519 20.52391703 25.53804974 37.16354296 34.02403408
#  18.35187795 31.18783038 29.64199657 27.9076536  28.85508923 38.85347584
#  40.06883763 34.59195316 37.98998502 42.4231089  26.78801647 43.95577355
#  21.58565501 43.44132017 30.76803223 33.86597682 22.78266198 36.6645288
#  38.09947915 32.39671421 30.6666037  19.15589424 42.15321766 32.48311512
#  29.85067373 20.0035588  48.07800538 56.04604306 56.62816583 34.3146787
#  41.41985811 35.89274078 37.05237909 50.11262167 39.10745875 23.46763751
#  53.26317847 20.83480908 21.3617519  27.34474373 51.45578982 24.98790706
#  38.71781714 49.8196276  37.30676131 28.37119438 37.85050546 33.70988198
#  38.85347584 41.65890775 37.74563349 37.48938054 31.27520635 35.90424021
#  58.92926675 44.53460402 46.4877492  48.21650987 41.168721   31.64970143
#  26.74673259 38.16779604 37.15970981 33.39024194 30.44140562 57.01749981
#  44.12010777 49.24314658 34.81605726 52.72748765 37.38500225 44.04736971
#  37.58099165 21.39300509 39.63242421 30.63130411 39.55526497 30.7599789
#  38.92119242 39.21587117 52.35170989 50.07400982 44.17859495 49.5049024
#  41.46211706 39.46238611 25.47130824 35.6578319  32.08435342 33.49206978
#  43.30606079 21.01979271 48.58154735 19.761078   30.48435924 18.66168829
#  37.85050546 29.41770641 29.83484748 28.6774792  33.75666874 35.94444239
#  34.14158154 28.07288347 49.42557976 23.71307075 20.54141302 26.65640418
#  38.16779604 44.33930929 40.32655932 28.21874664 36.20836162 30.73637706
#  17.90150634 55.54548576 39.6533663  25.73600155 58.67046336 43.25015394
#  45.60312758 27.4702651  44.57628989 19.96247591 34.10099233 38.96394504
#  34.23299165 41.00574889 39.08189449 30.09069844 28.31015675 51.45509515
#  25.70366666 41.52848113 60.88782046 38.20200166 33.92298032 28.88476704
#  32.18047739 14.33844559 37.43041463 27.79049318 23.9927096  30.72201955
#  33.39446212 43.13356661 38.67429044 23.94229069 18.48220754 55.71563049
#  28.38711499 29.71434758 61.90552311 42.98238662 51.33076211 21.44490769
#  34.50584494 29.13806756 57.98213875 33.25518355 40.52580343 37.65116432
#  33.84218893 42.70107802 33.0124074  51.70524225 24.69568707 28.65594908
#  54.01753498 39.08189449 48.15437559 42.64181676 45.51791501  3.60876581
#  33.92298032 52.51457536 19.92001597 22.22533708 16.41858089 32.12199021
#  17.02513903 64.51401244 29.58479208 39.08189449 43.06917456 31.32219411
#  35.51147507 39.94815168 26.13497918 42.28491203 31.52251032 48.36669719
#  20.18432225 44.20797742 40.75658915 57.77523795 36.27194971 44.67171919
#  32.72422153 45.28398121 49.00941377 37.48132721 31.95145844 51.44300769
#  45.82831339 27.30778667 46.84080584 49.7388362  47.20688243 30.62638926
#  35.94169095 50.19175827 17.50892724 43.51954617 36.4788505  41.63992808
#  34.53671108 49.72674874 37.72971288 16.9392318  63.6328097  31.4917508
#  40.50200594 40.07287176 51.78221543 26.92071046 30.76330343 25.39601973
#  17.53143244 30.08520784 34.82185282 27.55872278 33.54888723 39.75264369
#  24.76508566 28.96713381 25.21870238 29.00959375 46.7266128  30.71937475
#  46.93881548 53.27141785 24.84618467 42.66943779 28.97283768 29.7302682
#  30.72634637 52.24938837 47.95189597 34.8310028  48.71040819 34.34740064
#  26.69130446 26.71056455 36.5768452  28.6504462  45.42070934 16.03711419
#  28.60729159 52.56647796 43.57253048 64.44272125 37.9731837  41.66696108
#  43.04144689 41.97440702 34.02403408 48.04469541 18.60222604 46.63537379
#  37.98417452 21.35879947 59.54520811 26.14519592 59.32115118 47.45985344
#  41.12674246 39.51979159 41.85577786 21.22669351 41.84899228 30.20747182
#  39.81515007 55.12067841 32.70595147 27.09488932 50.73993853 20.37313902
#  28.71737375 23.29956183 40.66763513 11.83260728 52.95285951 18.15470022
#  21.7564944  51.35965091 56.62816583 26.46434229 46.72659785 40.40254249
#  41.66951153 39.73032454 32.64214745 52.01506753 30.14151934 33.84916056
#  49.84529582 53.16428812 36.32403836 44.29773273 59.4245544  39.81898322
#  26.99049609 43.5323283  21.07100065 24.09915961 37.9147882  25.14822209
#   7.29193941 52.12505533 50.59475509 40.41296022 33.35181613 29.81116622
#  44.52075513 25.59967541 50.24582428 26.48203927 41.13697414 41.92486882
#  34.52688139 37.38283884 22.46261035 37.00854476 35.11977669 41.69291238
#  36.73411344 22.80653195 42.18858707 46.53119649 33.746452   55.12067841
#  36.78464165 52.44145026 36.3169601  50.29811392 36.71936889 36.74779122
#  48.3757432  47.74589083 30.53684987 13.43337554 32.08945432 65.10048733
#  41.44894789 29.98907159 49.97837685 30.74463138 47.3619531  38.71881943
#  44.68380666 27.67027369 24.26979801 38.78800475 43.28061811 56.03616618
#  42.28254763 58.34658819 51.51721449 28.07033302 32.53028892 47.86523921
#  37.25142755 31.66976281 27.11297334 22.43076913 38.55879975 49.59994467
#  43.90917284 21.21686381 41.92084963 30.65401029 46.57602084 43.91762815
#  24.2986868  26.73022394 37.97612119 51.3062945  26.23985115 46.98765902
#  31.43896749 21.59784911 47.91022505 28.46693131 43.08490912 41.91012428
#  44.77040855 37.33861747 30.71132141 45.79755387 24.88686824 29.7422613
#  31.75919556 35.37456089 44.21171887 34.16791988 23.84704743 40.26905948
#  25.18075798 41.31931296 24.52623701 19.64646803 51.05398133 72.16809443
#  30.0990594  36.87614345 17.62570062 47.47194091 52.78124604 27.72237728
#  43.85306499 59.88149566 35.84358962 35.99005308 25.73600155 31.00382182
#  26.86880786 39.60678053 29.12598009 43.5301649  31.21525042 48.33425833
#  38.77738603 44.80441318 35.84025014 45.95737522 34.59195316 30.37545314
#  40.77978901 34.86992228 32.45078022 64.28661146 59.98057206 23.02808561
#  50.91076298 25.14822209 30.01973675 56.72942058 35.12911272 44.41419849
#  28.70282753 44.23726819 39.43830554 44.23708214 22.45199163 48.87505004
#  34.10099233 31.6628706  52.04356928 57.14105877 49.44258207 38.81061658
#  34.45670872 28.55500195 35.6888841  29.24913706 40.73830414 35.17973262
#  36.71848818 30.48435924 69.23364551 39.07894206 57.85276929 43.20336718
#  35.07082652 28.38801065 28.15220612 39.36153334 41.33395088 31.4053499
#  38.40270491 24.59838704 39.08367085 33.80090505 33.97310655 58.67046336
#  38.20750454 43.95410381 45.20357686 32.62769558 25.57550048 31.63506351
#  31.99096595 43.62265671 38.06182743 40.49011946 43.68822216 35.03386946
#  41.56788468 44.63760793 38.43740421 37.638536   44.57794468 47.40068653
#  48.72244848 27.93694437 44.32741055 26.47840711 48.43786254 49.72674874
#  41.0587332  33.69524406 26.12415947 38.12454707 37.0621171  49.35540709
#  44.02614721 31.64458559 34.4448073  24.65214542 25.00639307 30.03477665
#  34.76554399 48.34251265 33.33520086 34.00711118 32.64020691 51.71331052
#  28.19407803 29.59502376 32.52882017 39.64019713 36.5843105  31.50512096
#  25.41724223 46.58706075 41.04114285 14.62191759 56.40987223 38.99343681
#  30.85137407 30.76252935 54.26261106 20.81997018 32.0316618  48.70068513
#  43.89954413 29.68819529 38.00973878 36.73842798 36.83467352 29.98248701
#  46.84140882 29.57673874 34.28999515 50.63112412 31.89955584 37.2280267
#  20.21449373 25.17721751 66.83099715 32.22765119 26.55114517 33.79470751
#  27.9807787  20.4098951  27.61631432 57.98213875 25.63545641 41.51853253
#  58.38570866 43.63318107 32.84974291 28.09647037 47.22828404 52.07207103
#  38.00513155 29.35479805 61.78836269 26.0233067  32.06548038 30.42479035
#  41.42791144 56.07842514 35.5044885  19.75212901 26.0233067  28.90776591
#  37.80391969 51.22510113 33.23159665 45.92443736 31.0882603  34.54221397
#  27.79944216 30.14368275 33.75666874 45.58082337 10.72230617 33.33598988
#  63.27830887 45.32654778 27.8978239  36.52219116 34.70342465 60.18178393
#  16.56601942 24.89139605 34.98924611 23.90463896 21.90333264 53.53170493
#  33.17675656 32.72422153 33.69485702 30.51620046 44.44545168 28.90776591
#  47.05538787 46.68070675 42.89776208 35.23636402 26.57108498 41.20892318
#  31.54974431 32.10812637 14.20613864 31.17869534 63.26343047 49.58057795
#  39.40430091 38.34580804 17.76281579 24.99577434 30.45251802 52.0293184
#  42.86405013 41.45936562 29.2806856  20.98450539 32.42974377 51.15128136
#  30.10742035 28.71462231 48.82532579 42.78148237 27.40596742 49.85511591
#  25.86064222 19.87932012 25.26882862 33.71461078 42.36513033 44.78043924
#  44.19392753 28.75207305 54.17610085 31.03754604 22.82373526 53.14275799
#  46.83334055 44.68794743 40.45995758 58.8726503  36.51727631 43.26616624
#  33.36606701 36.44670166 23.36364626 32.61157398 45.01220963 47.10600778
#  50.44870588 42.33248781 53.64827732 48.64239893 35.51019237 40.15582656
#  26.92729504 34.02560946 28.66213168 47.45023434 29.07996741 38.76441785
#  53.02392784 25.28199779 45.28398121 33.31091929 46.67116973 38.31718472
#  25.44044209 31.43896749 24.49370112 24.88941869 48.70068513 36.46932843
#  44.02673524 30.03290592 45.82260951 24.01649749 30.94289082 52.86421578
#  52.08338441 24.65450982 43.11891375 11.37574544 28.62940975 26.78762943
#  27.34032255 51.32222739 38.67889766 51.81622006 26.75362479 27.93694437
#  49.91850301 36.79249399 38.54816609 18.3445987  28.51263637 38.77336684
#  37.39050513 35.46901513 41.83954962 51.68902895 34.41797529 49.41752643
#  55.26929301 20.21174229 42.93904596 58.57925424 29.2150258  22.72170643
#  40.2859701  35.53319124 19.24396488 46.15198756 38.06969471 20.84355708
#  46.10244936 57.80157629 40.86313085 38.2840608  35.84025014 36.07929979
#  47.5289444  54.25217838 51.73984985 39.08572763 43.28247389 40.02019508
#  33.85407541 31.03008074 39.59763055 34.10099233 46.54181521 42.26260783
#  40.30680556 48.83484786 35.43893533 26.52440485 26.83038205 26.54072744
#  37.80391969 63.54031789 26.36763029 31.95254014 32.43858612 17.10996456
#  32.62769558 49.67671687 44.86359503 38.16544391 21.43025483 39.94784406
#  33.09910365 27.37619791 30.27637674 20.84689655 17.58097064 42.20048849
#  31.25987378 32.73641563 17.61587093 21.91650181 38.54964978 49.39815971
#  41.28312998 47.75374317 58.00847709 34.54408469 47.75374317 38.11795021
#  35.23526737 34.9658602  38.09014313 43.49194008 34.5560778  42.04753213
#  24.47836854 31.78131371 40.24212083 76.72876422 25.08934786 38.90585984
#  53.79213088 26.54582834 43.12186618 29.68888996 33.14185627 33.01202035
#  50.89267896 27.89162635 34.08987993 50.5635019  35.27734028 26.87922559
#  40.95582365 39.94815168 52.67141205 32.59202122 28.52796895 17.8889252
#  45.11738922 15.71010054 46.32174525 40.76298768 39.47938843 26.06695498
#  28.97283768 27.02392763 61.10377687 30.655092   26.4813446  26.926908
#  30.11006516 44.77552439 48.47905206 47.82854761 33.40616255 41.01194644
#  21.4481528  39.47938843 41.63992808 34.5168507   9.31202442 45.43534725
#  28.537893   28.61712129 44.96149537 42.92312268 48.22397517 34.18512319
#  18.75309841 23.10700627 45.19660523 19.82594878 36.84676099 31.43218191
#  35.73901033 47.76230511 43.82238489 26.78762943 42.9701131  33.51468161
#  41.23162937 46.99581898 31.68154265 28.40481197 26.94370933 26.28722594
#  34.48521047 53.55509084 54.92861652 61.81981687 44.69256959 34.29747539
#  41.7806754  34.33423146 45.96060539 42.48926238 32.15658287 25.77031381
#  48.39038111 49.04677014 27.36380282 37.57657047 47.33906086 26.57001555
#  25.52636159 43.23785054 52.40253078 28.11239099 27.36429649 41.58470095
#  40.44421341 41.46595021 31.12442834 33.95512917 47.48837013 49.89825558
#  41.75089095 32.37253928 43.00077826 19.3150332  36.4022793  40.05931555
#  28.38752658 42.9913356  53.86490118 30.13031259 32.67360163 39.24309023
#  10.45308504 48.10670812]
